# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm 
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_params # вывод результатов тестирования
from statsmodels.iolib.summary2 import summary_col # вывод результатов тестирования
from statsmodels.stats.outliers_influence import variance_inflation_factor # VIF
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/wage2.csv')
df['age_urban'] = df['age']*df['urban']
df['IQ_urban']=df['IQ']*df['urban']
df
# Out:
#      wage  hours   IQ  KWW  educ  exper  tenure  age  married  black  south  \
# 0     769     40   93   35    12     11       2   31        1      0      0
# 1     808     50  119   41    18     11      16   37        1      0      0
# 2     825     40  108   46    14     11       9   33        1      0      0
# 3     650     40   96   32    12     13       7   32        1      0      0
# 4     562     40   74   27    11     14       5   34        1      0      0
# ..    ...    ...  ...  ...   ...    ...     ...  ...      ...    ...    ...
# 930   520     40   79   28    16      6       1   30        1      1      1
# 931  1202     40  102   32    13     10       3   31        1      0      1
# 932   538     45   77   22    12     12      10   28        1      1      1
# 933   873     44  109   25    12     12      12   28        1      0      1
# 934  1000     40  107   32    12     17      18   35        1      0      1
#
# ...

# %%
model = smf.ols(data = df , formula = 'np.log(wage)~ age + urban+age_urban + IQ+IQ_urban').fit()
model_1 = smf.ols(data = df , formula = 'age~ urban+age_urban+IQ+IQ_urban').fit()
model_2 = smf.ols(data = df , formula = 'urban~  age + IQ +age_urban+IQ_urban').fit()
model_3 = smf.ols(data = df , formula = 'age_urban~age+ IQ + urban+IQ_urban ').fit()
model_1.params.round(3)
# Out:
# Intercept    33.242
# urban       -33.242
# age_urban     1.000
# IQ           -0.001
# IQ_urban      0.001
# dtype: float64

# %%
model_1.rsquared
# Out:
# 0.6988700887158363

# %%
VIF_1 = 1/(1 - model_1.rsquared.round(3))
VIF_1.round(2)
# Out:
# 3.32

# %%
VIF_2 = 1/(1 - model_2.rsquared.round(3))
VIF_2.round(2)
# Out:
# 166.67

# %%
VIF_3 = 1/(1 - model_3.rsquared.round(3))
VIF_3.round(2)
# Out:
# 111.11
